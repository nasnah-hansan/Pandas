# %% [markdown]
# <a href="https://colab.research.google.com/github/nasnah-hansan/Pandas/blob/main/Pandas0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# Series, DataFrame 생성 방법
s = pd.Series([1, 3, 4, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    4.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
# random data생성 입력
df = pd.DataFrame(np.random.randn(6, 5), index = dates, columns = list("abcde"))
df
# Out:
#                    a         b         c         d         e
# 2013-01-01 -0.894525 -1.931177  0.383721  0.260413 -0.036796
# 2013-01-02 -1.692972  1.008463 -1.371807  1.579151 -0.636499
# 2013-01-03  1.686874 -1.022911 -0.771209 -1.126336  0.522092
# 2013-01-04 -1.279408 -0.986636 -0.238795 -0.075500 -0.743968
# 2013-01-05 -0.328741 -1.192554  1.556141 -0.614941  1.171303
# 2013-01-06 -1.588734 -0.670307 -0.522053  1.110277 -0.730229

# %%
# 딕셔너리를 키는 열 레이블, 값은 행(레코드)
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(3)), dtype="float32"),
        "D": np.array([3] * 3, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test"]),
        "F": "Foo"
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  Foo
# 1  1.0 2013-01-02  1.0  3  train  Foo
# 2  1.0 2013-01-02  1.0  3   test  Foo

# %%
# DataFrame은 다양한 data type을 가진다
df.dtypes
# Out:
# a    float64
# b    float64
# c    float64
# d    float64
# e    float64
# dtype: object

# %%
# Viewing data
df.head()
# Out:
#                    a         b         c         d         e
# 2013-01-01 -0.894525 -1.931177  0.383721  0.260413 -0.036796
# 2013-01-02 -1.692972  1.008463 -1.371807  1.579151 -0.636499
# 2013-01-03  1.686874 -1.022911 -0.771209 -1.126336  0.522092
# 2013-01-04 -1.279408 -0.986636 -0.238795 -0.075500 -0.743968
# 2013-01-05 -0.328741 -1.192554  1.556141 -0.614941  1.171303

# %%
df.tail(3)
# Out:
#                    a         b         c         d         e
# 2013-01-04 -1.279408 -0.986636 -0.238795 -0.075500 -0.743968
# 2013-01-05 -0.328741 -1.192554  1.556141 -0.614941  1.171303
# 2013-01-06 -1.588734 -0.670307 -0.522053  1.110277 -0.730229

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-0.89452543, -1.93117699,  0.38372119,  0.26041267, -0.03679647],
#        [-1.69297247,  1.00846272, -1.37180655,  1.57915133, -0.6364988 ],
#        [ 1.6868735 , -1.02291105, -0.77120903, -1.12633581,  0.52209175],
#        [-1.2794078 , -0.98663581, -0.23879549, -0.07549963, -0.74396821],
#        [-0.32874137, -1.19255373,  1.55614078, -0.61494108,  1.17130341],
#        [-1.58873368, -0.67030689, -0.52205265,  1.11027728, -0.73022933]])

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'Foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'Foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'Foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               a         b         c         d         e
# count  6.000000  6.000000  6.000000  6.000000  6.000000
# mean  -0.682918 -0.799187 -0.160667  0.188844 -0.075683
# std    1.263538  0.980361  1.021774  1.023011  0.787829
# min   -1.692972 -1.931177 -1.371807 -1.126336 -0.743968
# 25%   -1.511402 -1.150143 -0.708920 -0.480081 -0.706797
# 50%   -1.086967 -1.004773 -0.380424  0.092457 -0.336648
# 75%   -0.470187 -0.749389  0.228092  0.897811  0.382370
# max    1.686874  1.008463  1.556141  1.579151  1.171303

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# a   -0.894525   -1.692972    1.686874   -1.279408   -0.328741   -1.588734
# b   -1.931177    1.008463   -1.022911   -0.986636   -1.192554   -0.670307
# c    0.383721   -1.371807   -0.771209   -0.238795    1.556141   -0.522053
# d    0.260413    1.579151   -1.126336   -0.075500   -0.614941    1.110277
# e   -0.036796   -0.636499    0.522092   -0.743968    1.171303   -0.730229

# %%
# axis=0 : Y축(행), axis=1 : X축(열)
# ascending=False : 내림차순
df.sort_index(axis=1, ascending=False)
# Out:
#                    e         d         c         b         a
# 2013-01-01 -0.036796  0.260413  0.383721 -1.931177 -0.894525
# 2013-01-02 -0.636499  1.579151 -1.371807  1.008463 -1.692972
# 2013-01-03  0.522092 -1.126336 -0.771209 -1.022911  1.686874
# 2013-01-04 -0.743968 -0.075500 -0.238795 -0.986636 -1.279408
# 2013-01-05  1.171303 -0.614941  1.556141 -1.192554 -0.328741
# 2013-01-06 -0.730229  1.110277 -0.522053 -0.670307 -1.588734

# %%
df.sort_values(by='b', ascending=False)
# Out:
#                    a         b         c         d         e
# 2013-01-02 -1.692972  1.008463 -1.371807  1.579151 -0.636499
# 2013-01-06 -1.588734 -0.670307 -0.522053  1.110277 -0.730229
# 2013-01-04 -1.279408 -0.986636 -0.238795 -0.075500 -0.743968
# 2013-01-03  1.686874 -1.022911 -0.771209 -1.126336  0.522092
# 2013-01-05 -0.328741 -1.192554  1.556141 -0.614941  1.171303
# 2013-01-01 -0.894525 -1.931177  0.383721  0.260413 -0.036796

# %%
df.a
df['a']
# Out:
# 2013-01-01   -0.894525
# 2013-01-02   -1.692972
# 2013-01-03    1.686874
# 2013-01-04   -1.279408
# 2013-01-05   -0.328741
# 2013-01-06   -1.588734
# Freq: D, Name: a, dtype: float64

# %%
df[0:3]
# Out:
#                    a         b         c         d         e
# 2013-01-01 -0.894525 -1.931177  0.383721  0.260413 -0.036796
# 2013-01-02 -1.692972  1.008463 -1.371807  1.579151 -0.636499
# 2013-01-03  1.686874 -1.022911 -0.771209 -1.126336  0.522092

# %%
df["20130102":"20130104"]
# Out:
#                    a         b         c         d         e
# 2013-01-02 -1.692972  1.008463 -1.371807  1.579151 -0.636499
# 2013-01-03  1.686874 -1.022911 -0.771209 -1.126336  0.522092
# 2013-01-04 -1.279408 -0.986636 -0.238795 -0.075500 -0.743968

# %%
df.loc[dates[0]]
# Out:
# a   -0.894525
# b   -1.931177
# c    0.383721
# d    0.260413
# e   -0.036796
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["a", "b"]]
# df.loc[1:3, ["a"]] - datetime는 index로 slice가 안된다
df.loc[dates[1:3], ["a", "b"]]
# Out:
#                    a         b
# 2013-01-02 -1.692972  1.008463
# 2013-01-03  1.686874 -1.022911

# %%
# loc는 유연하고 여러 항목 선택이 가능하지만, at은 단일 값을 위한 고성능 기능입니다.
df.loc[dates[0], "a"]
# Out:
# np.float64(-0.8945254251696273)

# %%
df.at[dates[0], "a"]
# Out:
# np.float64(-0.8945254251696273)

# %%
# selection by postion
df.iloc[3]
# Out:
# a   -1.279408
# b   -0.986636
# c   -0.238795
# d   -0.075500
# e   -0.743968
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    a         b
# 2013-01-04 -1.279408 -0.986636
# 2013-01-05 -0.328741 -1.192554

# %%
df.iloc[[1,2,4], [0,2]]
# Out:
#                    a         c
# 2013-01-02 -1.692972 -1.371807
# 2013-01-03  1.686874 -0.771209
# 2013-01-05 -0.328741  1.556141

# %%
df.iloc[1:3, :]
# Out:
#                    a         b         c         d         e
# 2013-01-02 -1.692972  1.008463 -1.371807  1.579151 -0.636499
# 2013-01-03  1.686874 -1.022911 -0.771209 -1.126336  0.522092

# %%
df.iat[1,1]
# Out:
# np.float64(1.0084627223517577)
